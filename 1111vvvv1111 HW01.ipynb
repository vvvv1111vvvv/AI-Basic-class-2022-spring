# %%
'''
작성자 : 박수영 2018930012 mak8mgt07@naver.com
작성일 : 2022.03.14

목적 : 인공지능기초와활용 수업을 위해 파이썬의 기초 개념과 용어를 이해하고, 활용하는 방법을 실습한다.
'''

'''
문제 3-1 : 입력 받은 값이 홀수이면 1을 출력하고 짝수이면 2을 출력하기
방법 : if 문을 사용한다.
'''
a=int(input())#정수를 입력받아 a에 카피
if a%2==0:
    print("문제 3-1: 2, 짝수입니다.")
else:
    print("문제 3-1: 1, 홀수입니다")
    
    
'''
문제 3-2 : 1.10부터 90까지의 합 구하기(10, 90포함) 2. 11부터 1111까지의 짝수의 합 구하기
방법 : for문을 사용한다.
'''
sum1 = 0
for i in range(10,91):
    sum1 += i
print("문제 3-2 sum1 : ",sum1)
sum2 = 0
for j in range(11,1112):
    if j%2 == 0:
        sum2 += j
print("문제 3-2 sum2 : ",sum2)

'''
문제 3-3 : 1. 10부터 500까지의 합 구하기(10, 500포함)  2.1부터 입력받은값(>1)까지의합 구하기
방법 : while문을 사용한다.
'''
sum3=0
i=10
while i<=500:
    sum3+=i
    i+=1
print("문제 3-3 sum3 : ",sum3)
i=1
sum4=0
while i<=a:
    sum4+=i
    i+=1
print("문제 3-3 sum4 : ",sum4)



import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

'''
문제 4-1 : 행이 9개 열이 12개이고 각각의 원소가 row*col-1인 이중배열을 만드시오
방법 : array를 사용한다.
'''
# COLUMN : 열,세로줄
# ROW : 행, 가로줄
board = [[i*j-1 for i in range(12)] for j in range(9)] 
for i in range(9):
    print(board[i])

'''
문제 4-2 : 1. 문제 4-1의 배열을 numpy 배열로 바꾸고 shape을 출력하시오  2. 1~15까지의 홀수를 원소로 갖는 배열을 만들고 크기를 (2,4)로 바꾸시오
방법 : numpy를 사용한다.
'''    
board2 = np.array(board)
print("4-1 배열의 shape : ",board2.shape)

board3 =np.arange(1,16,2)
print("1~15의 홀수를 원소로 갖는 배열 board3 : ",board3)
board4=board3.reshape(2,4)
print("1~15의 홀수를 원소로 갖는 배열 board3의 (2,4)형태 : ",board4)
    

'''
문제 4-3 : 1. 𝑿~𝑵(𝟏𝟎, 𝟑𝟐)인 정규 분포를 따르는 난수 100개를 생성하는 numpy 코드를 작성하시오. 2. 1~100 사이 정수를 (10,10) 사이즈로 생성하는 코드를 작성하시오
방법 : numpy를 사용한다.
'''    
board5=np.random.normal(loc=10.0, scale=3, size=100)
print(board5)
board6=np.random.randint(1,101,size=(10,10))
print(board6)
    
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

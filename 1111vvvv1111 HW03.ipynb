# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
delivery=pd.read_csv('/kaggle/input/stats-ex3/delivery.csv')
a1=pd.read_csv('/kaggle/input/stats-ex3/a1.csv')
a2=pd.read_csv('/kaggle/input/stats-ex3/a2.csv')
td=pd.read_csv('/kaggle/input/stats-ex3/test_data.csv')
d1=pd.read_csv('/kaggle/input/stats-ex3/data1.csv',encoding='cp949') #엑셀파일을 그대로 읽어주기

# %%
delivery

# %%
x=delivery['거리']
y=delivery['시간']

# %%
x.shape

# %%
x1=np.array(x)  #x1이 np array로 생성\
x2=x1.reshape(-1,1) # 15행 1열
x2.shape

# %%
from sklearn.linear_model import LinearRegression #리니어 모델
lin_reg=LinearRegression()#괄호 꼭하기
lin_reg.fit(x2,y)

# %% [markdown]
# # **문제1 delvery.csv 데이터에서  x를 거리, y를  시간으로  하여  선형  회귀  계수를  구하고  결과  그래프를  그리 시오.**

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'o')
plt.plot(x, lin_reg.predict(x2))

# %%
a=lin_reg.coef_  #선형회귀 계수
b=lin_reg.intercept_  # b
a,b

# %% [markdown]
# # **문제2 test_data.csv 데이터를  불러와서 각각의  독립변수  x1, x2, x3, x4에 대하여  y와의  (단순)선형회귀 계수를  구하고  결과를  그래프로  그리시오.**

# %%
td

# %%
x1=td['x1']
x2=td['x2']
x3=td['x3']
x4=td['x4']
y=td['y']

# %%
Ax1=np.array(x1)
Ax2=np.array(x2)
Ax3=np.array(x3)
Ax4=np.array(x4)

# %%
r_Ax1=Ax1.reshape(-1,1)
r_Ax2=Ax2.reshape(-1,1)
r_Ax3=Ax3.reshape(-1,1)
r_Ax4=Ax4.reshape(-1,1)
r_Ax1.shape

# %%
lin_reg.fit(r_Ax1,y)  #r_Ax1과 y를 선형회귀

# %%
import matplotlib.pyplot as plt
plt.plot(x1, y, 'o')
plt.plot(x1, lin_reg.predict(r_Ax1))
a=lin_reg.coef_  #선형회귀 계수
b=lin_reg.intercept_  # b
a,b

# %%
lin_reg.fit(r_Ax2,y)
plt.plot(x2, y, 'o')
plt.plot(x2, lin_reg.predict(r_Ax2))
a=lin_reg.coef_  #선형회귀 계수
b=lin_reg.intercept_  # b
a,b

# %%
lin_reg.fit(r_Ax3,y)
plt.plot(x3, y, 'o')
plt.plot(x3, lin_reg.predict(r_Ax3))
a=lin_reg.coef_  #선형회귀 계수
b=lin_reg.intercept_  # b
a,b

# %%
lin_reg.fit(r_Ax4,y)
plt.plot(x4, y, 'o')
plt.plot(x4, lin_reg.predict(r_Ax4))
a=lin_reg.coef_  #선형회귀 계수
b=lin_reg.intercept_  # b
a,b

# %% [markdown]
# # **문제3.  2번을 다중회귀(4개의  독립변수와  1개의  종속변수)를  이용하여  계수를  구하시오.**

# %%
from sklearn.model_selection import train_test_split

x=td[['x1','x2','x3','x4']]
y=td[['y']]
train_x,test_x, train_y, test_y=train_test_split(x,y,test_size=0.2, stratify=y)
np.unique(train_y, return_counts=True)

# %%
ilin=LinearRegression()
ilin.fit(train_x, train_y)

# %%
x1

# %%
ia=ilin.coef_
ib=ilin.intercept_
ia, ib #입력값이 4차원이어서 coefficient도 4개가 나온다,, b는 1개가 나온다, 이것이 다중회귀다,

# %%
plt.plot(train_x, train_y,'o')
